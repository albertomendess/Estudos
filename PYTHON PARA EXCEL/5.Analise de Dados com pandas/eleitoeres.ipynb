# %%
import pandas as pd

# %%
caminho = "C:/Users/alber/OneDrive/Documentos/ESTUDOS/PYTHON PARA EXCEL/5.Analise de Dados com pandas/INFORMAÇÕES PREFEITOS DE PERNAMBUCO.xlsx"

# %%
df = pd.read_excel(caminho)
df.head()
# Out:
#    COD_IBGE                  NM_UE  DS_CARGO  SQ_CANDIDATO  NR_CANDIDATO  \
# 0   2600054           ABREU E LIMA  PREFEITO  170002212863            40
# 1   2600054           ABREU E LIMA  PREFEITO  170002008393            33
# 2   2600054           ABREU E LIMA  PREFEITO  170002323972            18
# 3   2600054           ABREU E LIMA  PREFEITO  170002107841            45
# 4   2600104  AFOGADOS DA INGAZEIRA  PREFEITO  170002105372            40
#
#                                NM_CANDIDATO EMAIL TELEFONE  \
# 0      FLAVIO VIEIRA GADELHA DE ALBUQUERQUE   NaN      NaN
# 1                  JAILTON LIMA DA ASSUNÇÃO   NaN      NaN
# 2             MANOEL ELIZEU DE SOUZA JUNIOR   NaN      NaN
# 3  MARCOS ANTONIO PEIXOTO DE SIQUEIRA FILHO   NaN      NaN
# 4   ALESANDRO PALMEIRA DE VASCONCELOS LEITE   NaN      NaN
#
#                    CANDIDATO SEM CARACTERES     TIPO DE CANDIDATURA  ...  \
# 0      FLAVIO VIEIRA GADELHA DE ALBUQUERQUE                REELEITO  ...
# ...

# %%
df2 = pd.DataFrame(df["SG_PARTIDO"]).drop_duplicates()
df2.values
# Out:
# array([['PSB'],
#        ['MOBILIZA'],
#        ['REDE'],
#        ['PSDB'],
#        ['PSD'],
#        ['MDB'],
#        ['PODE'],
#        ['REPUBLICANOS'],
#        ['PT'],
#        ['PDT'],
#        ['PSOL'],
#        ['PP'],
#        ['AVANTE'],
#        ['AGIR'],
#        ['DC'],
#        ['SOLIDARIEDADE'],
#        ['UNIÃO'],
#        ['PL'],
#        ['PRD'],
#        ['PV'],
#        ['PCB'],
#        ['UP'],
#        ['NOVO'],
#        ['PRTB'],
#        ['PCO'],
#        ['PSTU'],
#        ['PC do B']], dtype=object)
